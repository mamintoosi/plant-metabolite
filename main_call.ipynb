# %% [markdown]
# ## M. Amintoosi
# ## کاوش الگوهای پرتکرار
# استخراج قوانین انجمنی

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%time
# %run main.py
# Out:
# Table info:  (5392, 2)
# Number of nodes in main file:  3251
# Number of nodes after prunning those nodes which have < min count=2 elements is: 1090
# Computing the largest connected graph...
#
# Number of sub graph nodes: 1051
# Sub graph info before dropping:  (1051, 620)
# Sub graph info:  (1051, 538)
# Computing the graph features...
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# Computing frequent itemsets...
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Number of Freq. Itemsets: 1526
# Computing adjacency Graphs by Frequently Itemsets...
# HBox(children=(FloatProgress(value=0.0, max=1526.0), HTML(value='')))
# Number of Freq. Itemsets: 1526
# Computing adjacency Graphs by Frequently Itemsets...
# HBox(children=(FloatProgress(value=0.0, max=1526.0), HTML(value='')))
# Number of Freq. Itemsets: 1526
# Computing adjacency Graphs by Frequently Itemsets...
# HBox(children=(FloatProgress(value=0.0, max=1526.0), HTML(value='')))
# Number of Freq. Itemsets: 1526
# Computing adjacency Graphs by Frequently Itemsets...
# HBox(children=(FloatProgress(value=0.0, max=1526.0), HTML(value='')))
# Number of Freq. Itemsets: 1526
# Computing adjacency Graphs by Frequently Itemsets...
# HBox(children=(FloatProgress(value=0.0, max=1526.0), HTML(value='')))
# Number of Freq. Itemsets: 1526
# Computing adjacency Graphs by Frequently Itemsets...
# HBox(children=(FloatProgress(value=0.0, max=1526.0), HTML(value='')))
# Number of Freq. Itemsets: 1526
# Computing adjacency Graphs by Frequently Itemsets...
# HBox(children=(FloatProgress(value=0.0, max=1526.0), HTML(value='')))
# Number of Freq. Itemsets: 1526
# Computing adjacency Graphs by Frequently Itemsets...
# HBox(children=(FloatProgress(value=0.0, max=1526.0), HTML(value='')))
# Number of Freq. Itemsets: 1526
# Computing adjacency Graphs by Frequently Itemsets...
# HBox(children=(FloatProgress(value=0.0, max=1526.0), HTML(value='')))
# Number of Freq. Itemsets: 1526
# Computing adjacency Graphs by Frequently Itemsets...
# HBox(children=(FloatProgress(value=0.0, max=1526.0), HTML(value='')))
# CPU times: user 5min 17s, sys: 4.94 s, total: 5min 22s
# Wall time: 5min 15s

# %%
# degreeG
# احتمالا خیلی از گیاهان تک متابولیتی در ای‌سی، در فایل مرجع بوده‌اند
# %run stat.py
# jadval
# , tmp_df
# num_common_nodes
# sns.barplot(min_count_list, num_common_nodes, palette = 'crest')#, color='blue')
# sns.cubehelix_palette(start=2, rot=0, dark=0, light=.95, reverse=True, as_cmap=True)
# plt.show()
# Out:
# Table info:  (5392, 2)
# Number of nodes in main file:  3251
# Computing common itemsets...
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# [54, 42, 33, 21, 16, 12, 11, 7, 4, 2]
# /home/mahmood/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# %run main_features.py
# Out:
# Table info:  (5392, 2)
# Number of nodes in main file:  3251
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# /mnt/g/My Drive/colabs/CoWork/Kohan/main_features.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['features_sum'] = features_sum
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# /mnt/g/My Drive/colabs/CoWork/Kohan/main_features.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['features_sum'] = features_sum
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# /mnt/g/My Drive/colabs/CoWork/Kohan/main_features.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['features_sum'] = features_sum
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# /mnt/g/My Drive/colabs/CoWork/Kohan/main_features.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['features_sum'] = features_sum
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# /mnt/g/My Drive/colabs/CoWork/Kohan/main_features.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['features_sum'] = features_sum
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# /mnt/g/My Drive/colabs/CoWork/Kohan/main_features.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['features_sum'] = features_sum
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# /mnt/g/My Drive/colabs/CoWork/Kohan/main_features.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['features_sum'] = features_sum

# %%
print(jadval.head())
plt.figure()
sns.lineplot(x="k", y="AP@k",
             hue="Min Count",# 
            #  style="Min Count",
             data=jadval)
# Out:
#    k min_freq     Method Name  AP@k  AR@k
# 0  1           Graph Features  1.00  0.00
# 1  3           Graph Features  0.33  0.00
# 2  5           Graph Features  0.20  0.00
# 3  7           Graph Features  0.19  0.00
# 4  9           Graph Features  0.15  0.00
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-8c0200429497> in <module>
#       4              hue="Min Count",#
#       5             #  style="Min Count",
# ----> 6              data=jadval)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     686         data=data, variables=variables,
#     687         estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
# --> 688         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#     689     )
#     690
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in __init__(self, data, variables, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     365         )
#     366
# --> 367         super().__init__(data=data, variables=variables)
#     368
#     369         self.estimator = estimator
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/_core.py in assign_variables(self, data, variables)
#     666             self.input_format = "long"
#     667             plot_data, variables = self._assign_variables_longform(
# --> 668                 data, **variables,
#     669             )
#     670
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/_core.py in _assign_variables_longform(self, data, **kwargs)
#     900
#     901                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 902                 raise ValueError(err)
#     903
#     904             else:
#
# ValueError: Could not interpret value `Min Count` for parameter `hue`

# %%
# رسم نمودار تکی 
min_count = 5
m, n = 2, 3
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle('AP@k for all subsets of features, Min Count = '+str(min_count))
for i in np.arange(m):
    for j in np.arange(n):
        ax = axes[i,j]
        ax.set(ylim=(-.1, 1.1))

index_subset = [1,5,9]
for x, k in enumerate(index_subset):
    df = jadval[(jadval['k']==k) & (jadval['Min Count']==min_count)]
    # print(df)
    # plt.figure()
    i, j = (x)//3, (x)%3
    ax=axes[i, j]
    sns.lineplot(ax=ax,
                x="Set No", y="AP@k",
                #  hue="k",# 
                #  style="Min Count",
                data=df)
    ax.set_title('k='+str(k))
    

#  show error bands
df = jadval[(jadval['Min Count']==min_count)]
ax=axes[1, 0]
sns.lineplot(ax=ax,
            x="Set No", y="AP@k",
            # hue="k",# 
            #  style="Min Count",
            data=df)
ax.set_title('k='+str(index))
# ax.set(ylim=(0, 1))

f = {'AP@k':'mean'} #'Min Count':'first',
df_mean_score = df.groupby(['Set No'], as_index=False).agg(f)
# نمودار وسطی قبلی با همین میانگین یکی هست
# sns.lineplot(ax=axes[1, 1],
#             x="Set No", y="AP@k",
#             data=df_mean_score)
x, y = df_mean_score['AP@k'].idxmax(),df_mean_score['AP@k'].max()
# ax=axes[1, 0]
ax.scatter(x, y, marker='o', color='r', s=100)
f_names = list(gf_df.keys().format())
best_idx = int(x)
best_features = [f_names[i] for i in indices[best_idx]]
features_list = '{:d}th subset,\nwhich contains\n{:d} elements:'.format(best_idx,len(best_features))
for i,s in enumerate(best_features):
    # if i==0:
    #     features_list = s
    # else:
    features_list += "\n"+s
ax.text(40, 0,features_list  , fontsize=12) #add text

#  show error bars and plot the 68% confidence interval (standard error):
df = jadval[(jadval['Min Count']==min_count)]
sns.lineplot(ax=axes[1, 1],
            x="Set No", y="AP@k",
            data=df, err_style="bars", ci=68)
ax=axes[1, 1]
# ax.set(ylim=(0, 1))
ax.scatter(x, y, marker='o', color='r', s=100)
ax.set_title('k='+str(index))
ax.text(40, 0,features_list  , fontsize=12) #add text
sns.lineplot(ax=axes[1, 1],
            x="Set No", y="AP@k",
            data=df_mean_score)

png_file_name = 'results/FS_{}_{}_{}_{}_mc{:d}_k{:d}-{:d}_apk.png'.format(working_file_name[:2], GT_file_name[:2], \
    node_objects, edge_objects, min_count, index[0],index[-1])
plt.savefig(png_file_name)

# %%
# رسم نمودار تکی 
m, n = 2, 3
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle('AP@k for all subsets of features, Min Count = '+str(min_count))
for i in np.arange(m):
    for j in np.arange(n):
        ax = axes[i,j]
        ax.set(ylim=(-.1, 1.1))

min_count_list = [1,2,3,4,5,6]
for x, min_count in enumerate(min_count_list):
    i, j = (x)//3, (x)%3
    ax=axes[i, j]
    df = jadval[(jadval['Min Count']==min_count)]
    ax=axes[i, j]
    sns.lineplot(ax=ax,
                x="Set No", y="AP@k",
                data=df)
    ax.set_title('k='+str(index))
    

    f = {'AP@k':'mean'} #'Min Count':'first',
    df_mean_score = df.groupby(['Set No'], as_index=False).agg(f)
    x, y = df_mean_score['AP@k'].idxmax(),df_mean_score['AP@k'].max()
    ax.scatter(x, y, marker='o', color='r', s=100)
    f_names = list(gf_df.keys().format())
    best_idx = int(x)
    best_features = [f_names[i] for i in indices[best_idx]]
    features_list = '{:d}th subset,\nwhich contains\n{:d} elements:'.format(best_idx,len(best_features))
    for i,s in enumerate(best_features):
        features_list += "\n"+s
    ax.text(40, 0,features_list  , fontsize=12) #add text

png_file_name = 'results/FS_{}_{}_{}_{}_mc{:d}-{:d}_k{:d}-{:d}_apk.jpg'.format(working_file_name[:2], GT_file_name[:2], \
    node_objects, edge_objects, min_count_list[0], min_count_list[-1], index[0],index[-1])
plt.savefig(png_file_name)

# %%
# all_features_sets = []
# for idx in range(len(indices)):
#     all_features_sets.append([f_names[i] for i in indices[idx]])
# for i,item in enumerate(all_features_sets):
#     print(i,item)

# %%
type(np.array([x]))
# Out:
# numpy.ndarray

# %%
# print(len(indices)*9)
# df = jadval.groupby(['Min Count','Set No']).size().reset_index(name='counts')
# df = jadval.groupby(['Min Count','Set No'])['AP@k'].describe()
# print(df.head())
df = jadval[jadval['Min Count']==1]
print(df.head())
# df = jadval.groupby(['Set No'])['AP@k'].describe()

# f = {'AP@k':'mean'} #'Min Count':'first',
# df_max_score = df.groupby(['Set No'], as_index=False).agg(f)
# df_max_score = df.groupby(['Set No'])['AP@k'].mean().reset_index(name='mAP@k')
print(df_max_score.head())
plt.figure()
sns.lineplot(x="Set No", y="AP@k",
             hue="k",# 
            #  style="Min Count",
             data=df)
# sns.lineplot(x="Set No", y="AP@k",
#             #  hue="k",# 
#             #  style="Min Count",
#              data=df_max_score)       

# for min_count in min_count_list:
#     tmp_df = jadval[jadval['Min Count']==min_count]
#     if min_count == min_count_list[0]:
#         df_max_score = tmp_df.groupby(['Set No'])['AP@k'].mean().reset_index(name='mAP@k')
#     else:
#         df_max_score.append(tmp_df.groupby(['Set No'])['AP@k'].mean().reset_index(name='mAP@k'))
#         # ,\
#         #      ignore_index=True)

# df_max_score = jadval.groupby(['Set No','Min Count'])['AP@k'].mean().reset_index(name='mAP@k')
# df_max_score = jadval[jadval['Min Count']==6].groupby(['Set No','Min Count'])['AP@k'].mean().reset_index(name='mAP@k')
# df_max_score = jadval[jadval['Min Count']==6].groupby(['Set No'])['AP@k'].mean().reset_index(name='mAP@k')
df_max_score = jadval[jadval['Min Count']==1]
df_max_score
plt.figure()
sns.lineplot(x="Set No", y="AP@k",
            #  hue="Min Count",# style="min_count",
             data=df_max_score)
# Out:
#    Min Count  Set No    k  AP@k
# 1       1.00    0.00 1.00  1.00
# 2       1.00    0.00 2.00  1.00
# 3       1.00    0.00 3.00  1.00
# 4       1.00    0.00 4.00  0.94
# 5       1.00    0.00 5.00  0.87
#    Set No  mAP@k
# 0    0.00   0.86
# 1    1.00   0.86
# 2    2.00   0.80
# 3    3.00   0.87
# 4    4.00   0.00
# <AxesSubplot:xlabel='Set No', ylabel='AP@k'>

# %%
# %%time
# %run feature_selection.py
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /mnt/g/My Drive/colabs/CoWork/Kohan/feature_selection.py in <module>
#      38 file_name = 'results/{}_{}_{}_{}_{}_{}.xlsx'.format(working_file_name[:2],GT_file_name[:2],node_objects,\
#      39     edge_objects,str(min_count),str(minFreq))
# ---> 40 df = pd.read_excel(file_name, sheet_name='gf_df', engine="openpyxl" , index_col=0)
#      41
#      42 GT_file = working_dir+GT_file_name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_base.py in __init__(self, io, engine)
#     822         self._io = stringify_path(io)
#     823
# --> 824         self._reader = self._engines[engine](self._io)
#     825
#     826     def __fspath__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_openpyxl.py in __init__(self, filepath_or_buffer)
#     483         """
#     484         import_optional_dependency("openpyxl")
# --> 485         super().__init__(filepath_or_buffer)
#     486
#     487     @property
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_openpyxl.py in load_workbook(self, filepath_or_buffer)
#     495
#     496         return load_workbook(
# --> 497             filepath_or_buffer, read_only=True, data_only=True, keep_links=False
#     498         )
#     499
#
# ~/anaconda3/lib/python3.7/site-packages/openpyxl/reader/excel.py in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     312     """
#     313     reader = ExcelReader(filename, read_only, keep_vba,
# --> 314                         data_only, keep_links)
#     315     reader.read()
#     316     return reader.wb
#
# ~/anaconda3/lib/python3.7/site-packages/openpyxl/reader/excel.py in __init__(self, fn, read_only, keep_vba, data_only, keep_links)
#     122     def __init__(self,  fn, read_only=False, keep_vba=KEEP_VBA,
#     123                   data_only=False, keep_links=True):
# --> 124         self.archive = _validate_archive(fn)
#     125         self.valid_files = self.archive.namelist()
#     126         self.read_only = read_only
#
# ~/anaconda3/lib/python3.7/site-packages/openpyxl/reader/excel.py in _validate_archive(filename)
#      94             raise InvalidFileException(msg)
#      95
# ---> 96     archive = ZipFile(filename, 'r')
#      97     return archive
#      98
#
# ~/anaconda3/lib/python3.7/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1238             while True:
#    1239                 try:
# -> 1240                     self.fp = io.open(file, filemode)
#    1241                 except OSError:
#    1242                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/AC_St_Plant_Met_5_5.xlsx'
# CPU times: user 31.1 ms, sys: 103 µs, total: 31.2 ms
# Wall time: 66.7 ms

# %%
# len(scores)
df
# Out:
#       Min Count  Set No    k  AP@k
# 2836       6.00    0.00 1.00  0.00
# 2837       6.00    0.00 2.00  0.12
# 2838       6.00    0.00 3.00  0.21
# 2839       6.00    0.00 4.00  0.23
# 2840       6.00    0.00 5.00  0.23
# ...         ...     ...  ...   ...
# 3398       6.00   62.00 5.00  0.33
# 3399       6.00   62.00 6.00  0.35
# 3400       6.00   62.00 7.00  0.36
# 3401       6.00   62.00 8.00  0.36
# 3402       6.00   62.00 9.00  0.35
#
# [567 rows x 4 columns]

# %% [markdown]
# min_count = 4, minFreq = 7, AP@k hybrid was better
#
# در روش متابولیت به عنوان نود، جواب خوبی نگرفتم
# البته نمی دانم که در جدول
# LR
# متابولیتی داریم که در جدول
# AC
# نباشه

# %%
# %run main_features.py
# Out:
# Table info:  (5392, 2)
# Number of unique nodes (Plants) in main file:  3251
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# /mnt/g/My Drive/colabs/CoWork/Kohan/main_features.py:160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['features_sum'] = features_sum
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# /mnt/g/My Drive/colabs/CoWork/Kohan/main_features.py:160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['features_sum'] = features_sum
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# /mnt/g/My Drive/colabs/CoWork/Kohan/main_features.py:160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['features_sum'] = features_sum
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# /mnt/g/My Drive/colabs/CoWork/Kohan/main_features.py:160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['features_sum'] = features_sum
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# /mnt/g/My Drive/colabs/CoWork/Kohan/main_features.py:160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['features_sum'] = features_sum
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# /mnt/g/My Drive/colabs/CoWork/Kohan/main_features.py:160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['features_sum'] = features_sum
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# /mnt/g/My Drive/colabs/CoWork/Kohan/main_features.py:160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['features_sum'] = features_sum

# %%
true_df
# Out:
#            C_ID       CAS ID                       Metabolite  \
# 0     C00002783   61276-17-3                        Acteoside
# 1     C00004144   29741-09-1  Apigenin 7-O-beta-D-glucuronide
# 2     C00004268   29741-10-4  Luteolin 7-O-beta-D-glucuronide
# 3     C00006177   51938-32-0                      Schaftoside
# 4     C00007444      58-61-7                        Adenosine
# ...         ...          ...                              ...
# 4035  C00037817  532929-70-7             Shogasulfonic acid A
# 4036  C00037818  532929-71-8             Shogasulfonic acid B
# 4037  C00037819  532929-72-9             Shogasulfonic acid C
# 4038  C00037820  532929-73-0             Shogasulfonic acid D
# 4039        NaN          NaN                              NaN
#
#      Molecular formula     Mw   Organism or InChIKey etc.
# 0            C29H36O15 624.21        Acanthus ebracteatus
# 1            C21H18O11 446.08        Acanthus ebracteatus
# 2            C21H18O12 462.08        Acanthus ebracteatus
# 3            C26H28O14 564.15        Acanthus ebracteatus
# 4           C10H13N5O4 267.10        Acanthus ebracteatus
# ...                ...    ...                         ...
# 4035         C21H26O8S 438.13  Zingiber officinale ROSCOE
# 4036         C20H24O8S 424.12  Zingiber officinale ROSCOE
# 4037         C19H22O8S 410.10  Zingiber officinale ROSCOE
# 4038        C21H26O10S 470.12  Zingiber officinale ROSCOE
# 4039               NaN    nan                         NaN
#
# [4040 rows x 6 columns]
